# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import psycopg2 as pg

# %% [markdown]
# Ćwiczenie 3

# %%
# db_string = "postgres://postgres:admin@localhost:5432/test"
# db = create_engine(db_string)
# connection_sqlalchemy = db.connect()
from multiprocessing import connection


connection = pg.connect(host='pgsql-196447.vipserv.org', port=5432, dbname='wbauer_adb', user='wbauer_adb', password='adb2020')

# %% [markdown]
# ### 1. Liczba kategorii filmów. ###

# %%
#1
sl = pd.read_sql('SELECT \
    COUNT(name) \
        FROM category', \
            con=connection)
print(sl)
# Out:
#    count
# 0     16
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/2968672298.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sl = pd.read_sql('SELECT \

# %% [markdown]
# W wypożyczali jest 16 kategorii filmów.

# %% [markdown]
# ### 2. LIsta kategorii w kolejności alfabetycznej.  ###

# %%
#2
s2 = pd.read_sql('SELECT name \
    FROM category \
        ORDER BY name \
            ASC', con=connection)
print(s2)
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/1239474922.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   s2 = pd.read_sql('SELECT name \

# %% [markdown]
# ### 3. Najstarszy i najmłodszy film w wypożyczalni.  ###

# %%
#3
s3 = pd.read_sql('SELECT title, \
    release_year FROM film \
        ORDER BY release_year \
            ASC \
                LIMIT 1', \
                    con=connection)
print(s3)
s4 = pd.read_sql('SELECT title, release_year FROM film ORDER BY release_year DESC LIMIT 1', con=connection)
print(s4)
# Out:
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/2317401092.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   s3 = pd.read_sql('SELECT title, \
#              title  release_year
# 0  Chamber Italian          2006
#              title  release_year
# 0  Chamber Italian          2006
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/2317401092.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   s4 = pd.read_sql('SELECT title, release_year FROM film ORDER BY release_year DESC LIMIT 1', con=connection)

# %% [markdown]
# Najmłodszy i najstarszy film pochodzą z 2006 roku.

# %% [markdown]
# ### 4. Liczba wypożyczeń w danym okresie czasu.  ###

# %%
s4 = pd.read_sql(
    "SELECT COUNT(rental_date) \
        FROM rental \
            WHERE rental_date >= '2005-07-01 00:00:00' and rental_date <= '2005-08-01 23:59:59'", \
                con=connection)
print(s4)
# Out:
#    count
# 0   7380
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/2927732750.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   s4 = pd.read_sql(

# %% [markdown]
# W tym okresie zostało wypożyczonych 7380 filmów.

# %% [markdown]
# ### 5. Liczba wypożyczeń w danym okresie czasu.  ###

# %%
s5 = pd.read_sql(
    "SELECT COUNT(rental_date) \
        FROM rental \
            WHERE rental_date >= '2010-01-01 00:00:00' and rental_date <= '2011-02-01 23:59:59'", \
                con=connection)
print(s5)
# Out:
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/2162587030.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   s5 = pd.read_sql(
#    count
# 0      0

# %% [markdown]
# W tym okresie zostało wypożyczonych 0 filmów.

# %% [markdown]
# ### 6. Największa płatność wypożyczenia  ###

# %%
#6
s6 = pd.read_sql('SELECT * \
    FROM payment \
        ORDER BY amount \
            DESC \
                LIMIT 1', \
                    con=connection)
print(s6)
# Out:
#    payment_id  customer_id  staff_id  rental_id  amount  \
# 0       20403          362         1      14759   11.99
#
#                 payment_date
# 0 2007-03-21 21:57:24.996577
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/1571227255.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   s6 = pd.read_sql('SELECT * \

# %% [markdown]
# ### 7. Klienci z Polka, Nigeria lub Bangladesz. ###

# %%
#7



s7 = pd.read_sql("SELECT country_id \
    FROM country\
        WHERE country = 'Poland' OR country = 'Nigeria' OR country = 'Bangladesh'\
    ", con=connection) #Znalezienie id krajów
s7_7 = pd.read_sql("SELECT city_id\
    FROM city where country_id ='12' OR country_id ='69' OR country_id ='76'"\
        ,con=connection) #Znalezienie id krajów na popdstawie id miast
s7_7_tp = tuple(s7_7["city_id"].values.tolist()) 
address_id = pd.read_sql("SELECT address_id\
    FROM address\
        WHERE city_id IN {}".format(s7_7_tp),\
            con=connection) #Znalezienie id adresów na podstawie id miast

address_id_tp = tuple(address_id["address_id"].values.tolist())

customer = pd.read_sql("SELECT *\
    FROM customer\
        WHERE address_id IN {}".format(address_id_tp), \
            con=connection) #znalezienie klientów na podstawie id adresów
customer
# Out:
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/1516522755.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   s7 = pd.read_sql("SELECT country_id \
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/1516522755.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   s7_7 = pd.read_sql("SELECT city_id\
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/1516522755.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   address_id = pd.read_sql("SELECT address_id\
# ...

# %% [markdown]
# ### 8. Miejsce zamieszkania członków persolenu ###

# %%
add_id = pd.read_sql("SELECT address_id \
    FROM staff"\
        , con=connection) #Znalezienie id krajów
add_id_tp = tuple(add_id["address_id"].values.tolist()) 
address = pd.read_sql("SELECT address, address2\
    FROM address WHERE address_id IN {}".format(add_id_tp)\
        ,con=connection) 

address
# Out:
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/316211809.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   add_id = pd.read_sql("SELECT address_id \
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/316211809.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   address = pd.read_sql("SELECT address, address2\
#                 address address2
# 0     23 Workhaven Lane     None
# 1  1411 Lillydale Drive     None

# %% [markdown]
# ### 9. Liczba pracowników w Argentynie lub Hiszpani ###

# %%
city_id = pd.read_sql("SELECT city_id\
    FROM address WHERE address_id IN {}".format(add_id_tp)\
        ,con=connection)
city_id_tp = tuple(city_id["city_id"].values.tolist()) 

country_id = pd.read_sql("SELECT country_id\
    FROM city WHERE city_id IN {}".format(city_id_tp)\
        ,con=connection)
country_id_tp = tuple(country_id["country_id"].values.tolist()) 

country = pd.read_sql("SELECT COUNT(*)\
    FROM country WHERE (country = 'Argentina' OR country = 'Spain' ) AND country_id IN {}".format(country_id_tp)\
        ,con=connection)
country
# Out:
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/3815125141.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   city_id = pd.read_sql("SELECT city_id\
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/3815125141.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   country_id = pd.read_sql("SELECT country_id\
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/3815125141.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   country = pd.read_sql("SELECT COUNT(*)\
#    count
# 0      0

# %% [markdown]
# ### 10. Kategorie wypożyczanych filmów ###

# %%
rental_id = pd.read_sql("SELECT rental_id\
    FROM payment"\
        ,con=connection)
rental_id_tp = tuple(rental_id["rental_id"].values.tolist()) 

inventory_id = pd.read_sql("SELECT inventory_id\
    FROM rental WHERE rental_id IN {}".format(rental_id_tp)\
        ,con=connection)
inventory_id_tp = tuple(inventory_id["inventory_id"].values.tolist()) 

film_id = pd.read_sql("SELECT film_id\
    FROM inventory WHERE inventory_id IN {}".format(inventory_id_tp)\
        ,con=connection)
film_id_tp = tuple(film_id["film_id"].values.tolist()) 
category_id = pd.read_sql("SELECT category_id\
    FROM film_category WHERE film_id IN {}".format(film_id_tp)\
        ,con=connection)
category_id_tp = tuple(category_id["category_id"].values.tolist()) 


name = pd.read_sql("SELECT name\
    FROM category WHERE category_id IN {}".format(category_id_tp)\
        ,con=connection)

name
# Out:
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/1689987539.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rental_id = pd.read_sql("SELECT rental_id\
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/1689987539.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   inventory_id = pd.read_sql("SELECT inventory_id\
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/1689987539.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   film_id = pd.read_sql("SELECT film_id\
# ...

# %% [markdown]
# ### 11.Kategorie filmów wypożyczonych w USA ###

# %%
cou_id = pd.read_sql("SELECT country_id\
    FROM country WHERE country = 'United States'"\
        ,con=connection)
cou_id_int = int(cou_id["country_id"].values)

city_id = pd.read_sql("SELECT city_id FROM city WHERE country_id = {}".format(cou_id_int),con=connection)
city_id_tp = tuple(city_id["city_id"].values.tolist()) 

adres_id = pd.read_sql("SELECT address_id\
    FROM address WHERE city_id IN {}".format(city_id_tp)\
        ,con=connection)
adres_id_tp = tuple(adres_id["address_id"].values.tolist())

customer_id = pd.read_sql("SELECT customer_id\
    FROM customer WHERE address_id IN {}".format(adres_id_tp)\
        ,con=connection)
customer_id_tp = tuple(customer_id["customer_id"].values.tolist()) 


inventory_id = pd.read_sql("SELECT inventory_id\
    FROM rental WHERE customer_id IN {}".format(customer_id_tp)\
        ,con=connection)
inventory_id_tp = tuple(inventory_id["inventory_id"].values.tolist()) 


film_id = pd.read_sql("SELECT film_id\
    FROM inventory WHERE inventory_id IN {}".format(inventory_id_tp)\
        ,con=connection)
film_id_tp = tuple(film_id["film_id"].values.tolist()) 


cat_id = pd.read_sql("SELECT category_id\
    FROM film_category WHERE film_id IN {}".format(film_id_tp)\
        ,con=connection)
cat_id_tp = tuple(cat_id["category_id"].values.tolist()) 


name = pd.read_sql("SELECT name\
    FROM category WHERE category_id IN {}".format(cat_id_tp)\
        ,con=connection)

name
# Out:
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/3861820629.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cou_id = pd.read_sql("SELECT country_id\
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/3861820629.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   city_id = pd.read_sql("SELECT city_id FROM city WHERE country_id = {}".format(cou_id_int),con=connection)
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/3861820629.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %% [markdown]
# ### 12. Znajdź wszystkie tytuły filmów, w których grał: Olympia Pfeiffer lub Julia Zellweger lub Ellen Presley ###

# %%
actor_id = pd.read_sql("SELECT actor_id\
    FROM actor WHERE (first_name = 'Olympia' AND last_name = 'Pfeiffer') OR (first_name = 'Julia' AND last_name = 'Zellweger') OR (first_name = 'Ellen' AND last_name = 'Presley')"\
           ,con=connection)
actor_id_tp = tuple(actor_id["actor_id"].values)

film_id = pd.read_sql("SELECT film_id FROM film_actor WHERE actor_id IN {}".format(actor_id_tp),con=connection)
film_id_tp = tuple(film_id["film_id"].values.tolist()) 

title = pd.read_sql("SELECT title\
    FROM film WHERE film_id IN {}".format(film_id_tp)\
        ,con=connection)
title
# Out:
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/3096292282.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   actor_id = pd.read_sql("SELECT actor_id\
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/3096292282.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   film_id = pd.read_sql("SELECT film_id FROM film_actor WHERE actor_id IN {}".format(actor_id_tp),con=connection)
# C:\Users\majga\AppData\Local\Temp/ipykernel_16172/3096292282.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...
