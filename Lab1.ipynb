# %% [markdown]
# Gabriel Maj
# Zadanie 1

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


image1 = cv2.imread('bib_1.jpg')
image2 = cv2.imread('bib_2.jpg')
plt.imshow(image1)
plt.xticks([]), plt.yticks([])  
plt.show()

plt.imshow(image2)
plt.xticks([]), plt.yticks([])  
plt.show()

# %% [markdown]
# Zadanie 3

# %%
def fun1(x):
    return np.power(x,2) + 5
x1 = np.linspace(-1,1)
plt.plot(x1,fun1(x1))
plt.title('X^2+5')

plt.title('X^2+5')
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

x2 = np.linspace(-6,6)
plt.plot(x2,fun1(x2))
plt.title('X^2+5')
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

x3 = np.linspace(0,5)
plt.title('X^2+5')
plt.plot(x3,fun1(x3))
plt.title('X^2+5')
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

# %% [markdown]
# Zadanie 4

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}
d = {'name': ['Kamil', 'Aleksandra', 'Gabriel', 'Grzegorz', 'Piotr'], 'surname': ['Kowalski', 'Nowak', 'Maj', 'Nowakowski','Kania'], 'age': [23,17,22,47,36], 'sex': ['Male', 'Female','Male','Male','Male']}
x = pd.DataFrame(data = d)
x.info(verbose=True)
x.describe()
x.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes
#          name   surname  age     sex
# 0       Kamil  Kowalski   23    Male
# 1  Aleksandra     Nowak   17  Female
# 2     Gabriel       Maj   22    Male
